# %%
# Import the Node class you created in node.py
from node import Node

# Implement your Stack class here
class Stack:
    def __init__(self):
        self.top = None

    def push(self, action):
        new_node = Node(action)
        new_node.next = self.top # points to the old top
        self.top = new_node # move top to new node

    def pop(self):
        #if not self.top:
            #return None
        removed_node = self.top
        self.top = self.top.next # move top to the next node
        return removed_node.action
    
    def peek(self):
        if self.top:
            return self.top.action
        #else:
            #return None
        
    def print_stack(self):
        current = self.top
        if not current:
            print("Stack is empty")
            return
        while current:
            print(f"- {current.action}")
            current = current.next # update current to next value

# %%
stack = Stack()

# %%
stack.push("Blue")
stack.print_stack()
# Out:
# - Blue

# %%
stack.push("jello")
stack.push("turquoise")
stack.push("black")
stack.push("grey")
stack.push("red")
stack.push("teal")
stack.push("cyan")
stack.push("orange")
stack.push("purple")
stack.push("green")

# %%
stack.print_stack()
# Out:
# - green
# - purple
# - orange
# - cyan
# - teal
# - red
# - grey
# - black
# - turquoise
# - jello
# - Blue

# %%
stack.pop()
# Out:
# 'green'

# %%
stack.print_stack()
# Out:
# - purple
# - orange
# - cyan
# - teal
# - red
# - grey
# - black
# - turquoise
# - jello
# - Blue

# %%
stack.peek()
# Out:
# 'purple'

# %%
def run_undo_redo():
    # Create instances of the Stack class for undo and redo
    undo_stack = Stack()
    redo_stack = Stack()

    while True:
        print("\n--- Undo/Redo Manager ---")
        print("1. Perform action")
        print("2. Undo")
        print("3. Redo")
        print("4. View Undo Stack")
        print("5. View Redo Stack")
        print("6. Exit")
        choice = input("Select an option: ")

        if choice == "1":
            action = input("Describe the action (e.g., Insert 'a'): ")
            # Push the action onto the undo stack and clear the redo stack
            undo_stack.push(action)
            redo_stack = Stack()
            print(f"Action performed: {action}")

        elif choice == "2":
            # Pop an action from the undo stack and push it onto the redo stack
            action = undo_stack.pop()
            redo_stack.push(action)
            

        elif choice == "3":
            # Pop an action from the redo stack and push it onto the undo stack
            redo = redo_stack.pop()
            undo_stack.push(redo)


        elif choice == "4":
            # Print the undo stack
            print("\nUndo Stack:")
            undo_stack.print_stack()
            

        elif choice == "5":
            # Print the redo stack
            print("\nRedo Stack:")
            redo_stack.print_stack()
            
            
        elif choice == "6":
            print("Exiting Undo/Redo Manager.")
            break
        else:
            print("Invalid option.")

if __name__ == "__main__":
    run_undo_redo()
# Out:
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Invalid option.
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: sex
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: flip
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: fly
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: dance
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: stutter
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: think
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Invalid option.
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: laugh at this new joke
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: cook
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Action performed: hold mug
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# Redo Stack:
# Stack is empty
# None
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# Undo Stack:
# - dance
# - fly
# - flip
# - sex
# None
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
#
# Redo Stack:
# - think
# - laugh at this new joke
# - cook
# - hold mug
# - None
# None
#
# --- Undo/Redo Manager ---
# 1. Perform action
# 2. Undo
# 3. Redo
# 4. View Undo Stack
# 5. View Redo Stack
# 6. Exit
# Exiting Undo/Redo Manager.
